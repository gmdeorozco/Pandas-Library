# %% [markdown]
# <a href="https://colab.research.google.com/github/gmdeorozco/Pandas-Library/blob/main/load_client_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-19053723-5d74-4360-a90f-fd4218905ccb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19053723-5d74-4360-a90f-fd4218905ccb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel(io.BytesIO(uploaded['NC Stre.xlsx']))

# %%
df.head()
# Out:
#     ID        Nombre        Apellido   Amount  Trades  Rank  Inactive
# 0  371    Suban Yuri  Valle Olivares  13279.0      13     1       NaN
# 1   70         Cesar       Gutierrez  11229.0       9     2       NaN
# 2  165        Isaias          Flores  10300.0       8     3       NaN
# 3  432  Gustavo Josê    Laguna Lôpez   8260.0       5     4       NaN
# 4    3        Anyelo  Briones Flores   8045.0       5     5       NaN

# %%
df.set_index('ID', inplace=True)

# %%
df.head()
# Out:
#            Nombre        Apellido   Amount  Trades  Rank  Inactive
# ID
# 371    Suban Yuri  Valle Olivares  13279.0      13     1       NaN
# 70          Cesar       Gutierrez  11229.0       9     2       NaN
# 165        Isaias          Flores  10300.0       8     3       NaN
# 432  Gustavo Josê    Laguna Lôpez   8260.0       5     4       NaN
# 3          Anyelo  Briones Flores   8045.0       5     5       NaN

# %%
df.fillna({'Inactive':0},inplace=True)

# %%
df.head()
# Out:
#            Nombre        Apellido   Amount  Trades  Rank  Inactive
# ID
# 371    Suban Yuri  Valle Olivares  13279.0      13     1       0.0
# 70          Cesar       Gutierrez  11229.0       9     2       0.0
# 165        Isaias          Flores  10300.0       8     3       0.0
# 432  Gustavo Josê    Laguna Lôpez   8260.0       5     4       0.0
# 3          Anyelo  Briones Flores   8045.0       5     5       0.0

# %%
df.Inactive = df.Inactive.astype('int32')

# %%
df.Amount = df.Amount.astype('int32')

# %%
df.head()
# Out:
#            Nombre        Apellido  Amount  Trades  Rank  Inactive
# ID
# 371    Suban Yuri  Valle Olivares   13279      13     1         0
# 70          Cesar       Gutierrez   11229       9     2         0
# 165        Isaias          Flores   10300       8     3         0
# 432  Gustavo Josê    Laguna Lôpez    8260       5     4         0
# 3          Anyelo  Briones Flores    8045       5     5         0

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-96dc98c7-12b7-4327-986f-6efd5a99ffd8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96dc98c7-12b7-4327-986f-6efd5a99ffd8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
new_df = pd.read_excel(io.BytesIO(uploaded['NC Stre.xlsx']))

# %%
new_df.head()
# Out:
#     ID        Nombre        Apellido   Amount  Trades  Rank  Inactive
# 0  371    Suban Yuri  Valle Olivares  13279.0      13     1       NaN
# 1   70         Cesar       Gutierrez  11229.0       9     2       NaN
# 2  165        Isaias          Flores  10300.0       8     3       NaN
# 3  432  Gustavo Josê    Laguna Lôpez   8260.0       5     4       NaN
# 4    3        Anyelo  Briones Flores   8045.0       5     5       NaN
